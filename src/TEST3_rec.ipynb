# %%
# !cd /Users/joshua/Desktop/REC_SYS_PROJECT && python pretrain_mf.py --dataset amazon-book --batch_size 8192
# Out:
# ...
#   MF Pre-training for NGCF
#   Dataset: amazon-book
# ...
#   Dataset loaded
#   #Users:      52,643
#   #Items:      91,599
#   #Train:   2,380,730
#   #Test:      603,378
#   Density:    0.00049
# ...
#
# Training MF for 200 epochs...
# --------------------------------------------------
#   Epoch   10 | loss 0.12188 | 11.2s
#   Epoch   20 | loss 0.07199 | 10.9s
#   Epoch   30 | loss 0.05122 | 11.6s
#   Epoch   40 | loss 0.03982 | 11.6s
#   Epoch   50 | loss 0.03250 | 11.2s
#   Epoch   60 | loss 0.02708 | 11.5s
#   Epoch   70 | loss 0.02320 | 11.1s
#   Epoch   80 | loss 0.02030 | 11.7s
#   Epoch   90 | loss 0.01801 | 11.3s
#   Epoch  100 | loss 0.01614 | 11.9s
#   Epoch  110 | loss 0.01472 | 10.5s
#   Epoch  120 | loss 0.01347 | 10.1s
#   Epoch  130 | loss 0.01264 | 10.3s
#   Epoch  140 | loss 0.01168 | 10.0s
#   Epoch  150 | loss 0.01097 | 9.9s
#   Epoch  160 | loss 0.01041 | 10.0s
#   Epoch  170 | loss 0.00981 | 9.9s
#   Epoch  180 | loss 0.00947 | 9.9s
#   Epoch  190 | loss 0.00895 | 9.9s
# ...
